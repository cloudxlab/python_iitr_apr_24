# %% [markdown]
# Q: Generate the stock prices for about 100,000 days using  some complex equation as mentioned below:
#
# stock prices = 2*sin(2x+10) + 5*sin(3x - 10) + random()
#
# stock prices: [1.2, 2.3, .... 100k]
#
# Q: Convert this data into X and y such that X.shape is about 100000x20 and shape of y is 100,000
#
#
# For example here:
# [1,2,3,4,2,12,2,4,5,6,7,8,9,9,9,9,0,1,2,3,4, 1,2, 0.5, 7, 8]
# ->
# X                                           y
# [1,2,3,4,2,12,2,4,5,6,7,8,9,9,9,9,0,1,2,3]      [4]
# [2,3,4,2,12,2,4,5,6,7,8,9,9,9,9,0,1,2,3,4,]     [1]
# [3,4,2,12,2,4,5,6,7,8,9,9,9,9,0,1,2,3,4, 1]     [2]
# [4,2,12,2,4,5,6,7,8,9,9,9,9,0,1,2,3,4, 1,2]     [0.5]
# [2,12,2,4,5,6,7,8,9,9,9,9,0,1,2,3,4, 1,2, 0.5]  [7]
# [12,2,4,5,6,7,8,9,9,9,9,0,1,2,3,4, 1,2, 0.5, 7] [8]
#
# Q: Build a model that can take 20 values and predict the next price.
