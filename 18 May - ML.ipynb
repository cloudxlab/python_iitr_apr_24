# %% [markdown]
# TODO:
#     1. We will end the session with atleast 5 problems on recursion
#     2.

# %%
def move1(n, src, target, aux):
    # print("Move ", n, "  from ", src , 'to', target)
    # print("Move %s from %s to %s" %(n, src, target))
    print(f"Move {n} from {src} to {target}")

# %%
move1(10, 'A', "B", "C")
# Out:
# Move 10 from A to B

# %%
def move2(src, target, aux):
    n = 2
    move1(n-1, src, aux, target)
    print("Move 2 from ", src , 'to', target)
    move1(n-1, aux, target, src)

# %%
move2('A', 'B', 'C')
# Out:
# Move 1 from A to C
# Move 2 from  A to B
# Move 1 from C to B

# %%
def move3(src, target, aux):
    move2(src, aux, target)
    print('Move 3 from ', src, target)
    move2(aux, target, src)

# %%
def tower_of_hanoi(n,src,target,aux):
    if n==1:
        print("Move disk "+str(n)+" from "+src+" to "+target)
    elif n==2:
        print("Move disk "+str(n)+" from "+src+" to "+aux)
        tower_of_hanoi(n-1,src,target,aux)
        print("Move disk "+str(n)+" from "+aux+" to "+target)
    else:
        print("Move disk "+str(n)+" from "+src+" to "+target)
        tower_of_hanoi(n-1,src,aux,target) 
        
tower_of_hanoi(3,'A','B','C')
# Out:
# Move disk 3 from A to B
# Move disk 2 from A to B
# Move disk 1 from A to C
# Move disk 2 from B to C

# %%
def move(n, source, target, auxiliary):
    if n == 1:
        print("Move disk 1 from", source, "to", target)
        return
    move(n - 1, source, auxiliary, target)
    print("Move disk", n, "from", source, "to", target)
    move(n - 1, auxiliary, target, source)

# Example usage
n_disk = 4

move(n_disk, 'A', 'C', 'B')
# Out:
# Move disk 1 from A to B
# Move disk 2 from A to C
# Move disk 1 from B to C
# Move disk 3 from A to B
# Move disk 1 from C to A
# Move disk 2 from C to B
# Move disk 1 from A to B
# Move disk 4 from A to C
# Move disk 1 from B to C
# Move disk 2 from B to A
# Move disk 1 from C to A
# Move disk 3 from B to C
# Move disk 1 from A to B
# Move disk 2 from A to C
# Move disk 1 from B to C

# %% [markdown]
# ```
# exp1 = exp2 [+/- exp2 +/- exp2] # 2 * 3^(5 + 1) + 4*5
# exp2 = exp3 * exp3
# exp3 = exp4 ^ exp4
# exp4 = (exp1)
# ```
# https://github.com/girisandeep/calcuchat/blob/master/lib/calc.dart

# %% [markdown]
# ebook - The C Programming Language Ritchie & kernighan -.doc

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Q: Write a wild card character matcher. * matches 0 or more chars. ? matches only one character.
#
#     a* -> abc, ab, ax, a
#     a? -> a1, a2, aa,
#     a*b -> axyzb, a123b, ab
#     a*b*c -> abc, abbbc, a1b1c
#     aa?b*:
#         match: aa1b, aaxby, aa1bcdeffgshshshsh
#         not match: aab, ab,
# ```
# def ismatch(pat, text):
#     return True/False
# ```

# %% [markdown]
# Riya Bindra to Everyone (18 May 2024, 11:50 PM)
# Sharing an approach I find the easiest for recursion:
# 1. Find out the simplest case (base case)
# 2. Assume your function solves the given problem- In our case TowerOfHanoi(n) moves n disks from source to target.
# 3. Find out a just smaller problem- In our case TowerOfHanoi(n-1)- Moves n-1 disks from source to destination
# 4. Write recurrence relation using step 3.

# %%
# Some problems for recursion:
    
# Q1. Solving Sudoku
# Q2. Solving Tictac To
# Q3. Print all permutation of a give list of unique characters

# %% [markdown]
# input: aaa$$cc$$eeee@@f&aaaee
# output: aaa3$$cc2$$eeee4@@f1&aaa3ee2

# %%
#Print all even numbers from 1 till 100
n = 1
while n <= 100:
    print("Checking: ", n)
    if n % 2 == 0:
        print(n)
    n = n+1
# Out:
# Checking:  1
# Checking:  2
# 2
# Checking:  3
# Checking:  4
# 4
# Checking:  5
# Checking:  6
# 6
# Checking:  7
# Checking:  8
# 8
# Checking:  9
# Checking:  10
# 10
# Checking:  11
# Checking:  12
# 12
# Checking:  13
# Checking:  14
# 14
# Checking:  15
# Checking:  16
# 16
# Checking:  17
# Checking:  18
# 18
# Checking:  19
# Checking:  20
# 20
# Checking:  21
# Checking:  22
# 22
# Checking:  23
# Checking:  24
# 24
# Checking:  25
# Checking:  26
# 26
# Checking:  27
# Checking:  28
# 28
# Checking:  29
# Checking:  30
# 30
# Checking:  31
# Checking:  32
# 32
# Checking:  33
# Checking:  34
# 34
# Checking:  35
# Checking:  36
# 36
# Checking:  37
# Checking:  38
# 38
# Checking:  39
# Checking:  40
# 40
# Checking:  41
# Checking:  42
# 42
# Checking:  43
# Checking:  44
# 44
# Checking:  45
# Checking:  46
# 46
# Checking:  47
# Checking:  48
# 48
# Checking:  49
# Checking:  50
# 50
# Checking:  51
# Checking:  52
# 52
# Checking:  53
# Checking:  54
# 54
# ...

# %%
# Print all numbers from arr
arr = [10,20,30,40]
i = 0
while i < len(arr):
    print(arr[i])
    i += 1  # i = i + 1
# Out:
# 10
# 20
# 30
# 40

# %%
# I want to multiple all numbers by 2

def doubleArr(arr):
    result = []
    i = 0
    while i < len(arr):
        val = arr[i]
        arr[i] *= 2
        result.append(val*2)
        print(result)
        i += 1  # i = i + 1
    return arr

# %%
arr = [10,20,30,40]
doubleArr(arr)
# Out:
# [20, 40, 60, 80]

# %%
import math
math.sqrt(13)
# Out:
# 3.605551275463989

# %% [markdown]
# Q1: Given two vectors (arrays or list of numbers)
#
#      return the difference of the two vectors
#      diff([1,2,3], [2,3,4]) => [-1, -1, -1]
#
#
# Q2: Given two vectors (arrays or list of numbers). Find absolute distance between them. L1 Distance.
#
#     abs_distance([1,2,3], [2, 3, 4]) -> 3
#     abs_distance([5,4,1], [2, 3, 4]) -> 3+1+3 = 7
#
# Q3: Given two 2D vectors representing two points, find the distance between two points.
#
#     distance([1,2], [3,5]) -> sqrt((3 - 1)**2 + (5-2)**2)
#         sqrt(13) = 3.605551275463989
#
# Q4: Given two 3D vectors representing two points, find the distance between two points.
#     distance3d([1, 2, 3], [2,3,4] ) -> math.sqrt(3)
#
# Q5: Generalize problem Q4 for n dimensions.
